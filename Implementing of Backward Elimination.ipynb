# %%
# importing libraries  
import numpy as np
import matplotlib.pyplot as plt 
import pandas as pd  ,os
os.chdir(r'C:\Users\meher\OneDrive\Desktop\T hub')

# %%
#importing datasets  
data_set= pd.read_csv('50_Startups.csv')

# %%
data_set
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
dummies=pd.get_dummies(data_set["State"])
dummies_df = dummies.astype(int)
dummies_df
# Out:
#     California  Florida  New York
# 0            0        0         1
# 1            1        0         0
# 2            0        1         0
# 3            0        0         1
# 4            0        1         0
# 5            0        0         1
# 6            1        0         0
# 7            0        1         0
# 8            0        0         1
# 9            1        0         0
# 10           0        1         0
# 11           1        0         0
# 12           0        1         0
# 13           1        0         0
# 14           0        1         0
# 15           0        0         1
# 16           1        0         0
# 17           0        0         1
# 18           0        1         0
# 19           0        0         1
# 20           1        0         0
# 21           0        0         1
# 22           0        1         0
# 23           0        1         0
# 24           0        0         1
# 25           1        0         0
# ...

# %%
df=pd.concat([data_set,dummies_df],axis=1)

# %%
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit  \
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94
#
#    California  Florida  New York
# 0           0        0         1
# 1           1        0         0
# 2           0        1         0
# 3           0        0         1
# 4           0        1         0

# %%
df.drop(["State",'California'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend     Profit  Florida  New York
# 0  165349.20       136897.80        471784.10  192261.83        0         1
# 1  162597.70       151377.59        443898.53  191792.06        0         0
# 2  153441.51       101145.55        407934.54  191050.39        1         0
# 3  144372.41       118671.85        383199.62  182901.99        0         1
# 4  142107.34        91391.77        366168.42  166187.94        1         0

# %%
# feature or indepents variable
x=df.drop(['Profit'],axis=1).values
x
# Out:
# array([[1.6534920e+05, 1.3689780e+05, 4.7178410e+05, 0.0000000e+00,
#         1.0000000e+00],
#        [1.6259770e+05, 1.5137759e+05, 4.4389853e+05, 0.0000000e+00,
#         0.0000000e+00],
#        [1.5344151e+05, 1.0114555e+05, 4.0793454e+05, 1.0000000e+00,
#         0.0000000e+00],
#        [1.4437241e+05, 1.1867185e+05, 3.8319962e+05, 0.0000000e+00,
#         1.0000000e+00],
#        [1.4210734e+05, 9.1391770e+04, 3.6616842e+05, 1.0000000e+00,
#         0.0000000e+00],
#        [1.3187690e+05, 9.9814710e+04, 3.6286136e+05, 0.0000000e+00,
#         1.0000000e+00],
#        [1.3461546e+05, 1.4719887e+05, 1.2771682e+05, 0.0000000e+00,
#         0.0000000e+00],
#        [1.3029813e+05, 1.4553006e+05, 3.2387668e+05, 1.0000000e+00,
#         0.0000000e+00],
#        [1.2054252e+05, 1.4871895e+05, 3.1161329e+05, 0.0000000e+00,
#         1.0000000e+00],
#        [1.2333488e+05, 1.0867917e+05, 3.0498162e+05, 0.0000000e+00,
#         0.0000000e+00],
# ...

# %%
# target variable or output
y=df["Profit"].values
y
# Out:
# array([192261.83, 191792.06, 191050.39, 182901.99, 166187.94, 156991.12,
#        156122.51, 155752.6 , 152211.77, 149759.96, 146121.95, 144259.4 ,
#        141585.52, 134307.35, 132602.65, 129917.04, 126992.93, 125370.37,
#        124266.9 , 122776.86, 118474.03, 111313.02, 110352.25, 108733.99,
#        108552.04, 107404.34, 105733.54, 105008.31, 103282.38, 101004.64,
#         99937.59,  97483.56,  97427.84,  96778.92,  96712.8 ,  96479.51,
#         90708.19,  89949.14,  81229.06,  81005.76,  78239.91,  77798.83,
#         71498.49,  69758.98,  65200.33,  64926.08,  49490.75,  42559.73,
#         35673.41,  14681.4 ])

# %%
# splitting data

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
#Training DataSet
x_train
# Out:
# array([[5.5493950e+04, 1.0305749e+05, 2.1463481e+05, 1.0000000e+00,
#         0.0000000e+00],
#        [4.6014020e+04, 8.5047440e+04, 2.0551764e+05, 0.0000000e+00,
#         1.0000000e+00],
#        [7.5328870e+04, 1.4413598e+05, 1.3405007e+05, 1.0000000e+00,
#         0.0000000e+00],
#        [4.6426070e+04, 1.5769392e+05, 2.1079767e+05, 0.0000000e+00,
#         0.0000000e+00],
#        [9.1749160e+04, 1.1417579e+05, 2.9491957e+05, 1.0000000e+00,
#         0.0000000e+00],
#        [1.3029813e+05, 1.4553006e+05, 3.2387668e+05, 1.0000000e+00,
#         0.0000000e+00],
#        [1.1994324e+05, 1.5654742e+05, 2.5651292e+05, 1.0000000e+00,
#         0.0000000e+00],
#        [1.0002300e+03, 1.2415304e+05, 1.9039300e+03, 0.0000000e+00,
#         1.0000000e+00],
#        [5.4205000e+02, 5.1743150e+04, 0.0000000e+00, 0.0000000e+00,
#         1.0000000e+00],
#        [6.5605480e+04, 1.5303206e+05, 1.0713838e+05, 0.0000000e+00,
#         1.0000000e+00],
# ...

# %%
y_train
# Out:
# array([ 96778.92,  96479.51, 105733.54,  96712.8 , 124266.9 , 155752.6 ,
#        132602.65,  64926.08,  35673.41, 101004.64, 129917.04,  99937.59,
#         97427.84, 126992.93,  71498.49, 118474.03,  69758.98, 152211.77,
#        134307.35, 107404.34, 156991.12, 125370.37,  78239.91,  14681.4 ,
#        191792.06, 141585.52,  89949.14, 108552.04, 156122.51, 108733.99,
#         90708.19, 111313.02, 122776.86, 149759.96,  81005.76,  49490.75,
#        182901.99, 192261.83,  42559.73,  65200.33])

# %%
# Test dataset
x_test
# Out:
# array([[6.6051520e+04, 1.8264556e+05, 1.1814820e+05, 1.0000000e+00,
#         0.0000000e+00],
#        [1.0067196e+05, 9.1790610e+04, 2.4974455e+05, 0.0000000e+00,
#         0.0000000e+00],
#        [1.0191308e+05, 1.1059411e+05, 2.2916095e+05, 1.0000000e+00,
#         0.0000000e+00],
#        [2.7892920e+04, 8.4710770e+04, 1.6447071e+05, 1.0000000e+00,
#         0.0000000e+00],
#        [1.5344151e+05, 1.0114555e+05, 4.0793454e+05, 1.0000000e+00,
#         0.0000000e+00],
#        [7.2107600e+04, 1.2786455e+05, 3.5318381e+05, 0.0000000e+00,
#         1.0000000e+00],
#        [2.0229590e+04, 6.5947930e+04, 1.8526510e+05, 0.0000000e+00,
#         1.0000000e+00],
#        [6.1136380e+04, 1.5270192e+05, 8.8218230e+04, 0.0000000e+00,
#         1.0000000e+00],
#        [7.3994560e+04, 1.2278275e+05, 3.0331926e+05, 1.0000000e+00,
#         0.0000000e+00],
#        [1.4210734e+05, 9.1391770e+04, 3.6616842e+05, 1.0000000e+00,
#         0.0000000e+00]])

# %%
y_test
# Out:
# array([103282.38, 144259.4 , 146121.95,  77798.83, 191050.39, 105008.31,
#         81229.06,  97483.56, 110352.25, 166187.94])

# %%
# fetting model

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
reg.predict(x_test)
# Out:
# array([103015.20159796, 132582.27760816, 132447.73845174,  71976.09851258,
#        178537.48221055, 116161.24230165,  67851.69209676,  98791.73374687,
#        113969.43533012, 167921.0656955 ])

# %%
reg.predict([[10,2,30,40,4]])
# Out:
# array([6989.17616742])

# %%
reg.score(x_train,y_train)
# Out:
# 0.9501847627493607

# %% [markdown]
# # By using linear Regression R2-score 0.950,all independent varaibles

# %% [markdown]
# Backward Elimination

# %%
x=np.append(arr=np.ones((50,1)).astype(int),values=x,axis=1)

# %%
x
# Out:
# array([[1.0000000e+00, 1.6534920e+05, 1.3689780e+05, 4.7178410e+05,
#         0.0000000e+00, 1.0000000e+00],
#        [1.0000000e+00, 1.6259770e+05, 1.5137759e+05, 4.4389853e+05,
#         0.0000000e+00, 0.0000000e+00],
#        [1.0000000e+00, 1.5344151e+05, 1.0114555e+05, 4.0793454e+05,
#         1.0000000e+00, 0.0000000e+00],
#        [1.0000000e+00, 1.4437241e+05, 1.1867185e+05, 3.8319962e+05,
#         0.0000000e+00, 1.0000000e+00],
#        [1.0000000e+00, 1.4210734e+05, 9.1391770e+04, 3.6616842e+05,
#         1.0000000e+00, 0.0000000e+00],
#        [1.0000000e+00, 1.3187690e+05, 9.9814710e+04, 3.6286136e+05,
#         0.0000000e+00, 1.0000000e+00],
#        [1.0000000e+00, 1.3461546e+05, 1.4719887e+05, 1.2771682e+05,
#         0.0000000e+00, 0.0000000e+00],
#        [1.0000000e+00, 1.3029813e+05, 1.4553006e+05, 3.2387668e+05,
#         1.0000000e+00, 0.0000000e+00],
#        [1.0000000e+00, 1.2054252e+05, 1.4871895e+05, 3.1161329e+05,
#         0.0000000e+00, 1.0000000e+00],
# ...

# %%
import statsmodels.api as sm 
x_opt=x[:,[0,1,2,3,4]]
#estimating the coefficients and other parameters using the OLS method.
regressor_OLS=sm.OLS(endog=y,exog=x_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.946
# Method:                 Least Squares   F-statistic:                     217.2
# Date:                Tue, 12 Mar 2024   Prob (F-statistic):           8.49e-29
# Time:                        16:24:39   Log-Likelihood:                -525.38
# No. Observations:                  50   AIC:                             1061.
# Df Residuals:                      45   BIC:                             1070.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5.011e+04   6647.870      7.537      0.000    3.67e+04    6.35e+04
# ...

# %%
import numpy as np

# Check for NaN values
#print(np.isnan(y).any())
print(np.isnan(x_opt).any())

# Check for infinite values
# Out:
# False

# %%
x_opt=x[:,[0,1,2,3]]
regressor_OLS=sm.OLS(endog=y,exog=x_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.948
# Method:                 Least Squares   F-statistic:                     296.0
# Date:                Tue, 12 Mar 2024   Prob (F-statistic):           4.53e-30
# Time:                        16:24:40   Log-Likelihood:                -525.39
# No. Observations:                  50   AIC:                             1059.
# Df Residuals:                      46   BIC:                             1066.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5.012e+04   6572.353      7.626      0.000    3.69e+04    6.34e+04
# ...

# %%
x_opt=x[:,[0,1,2]]
regressor_OLS=sm.OLS(endog=y,exog=x_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.948
# Model:                            OLS   Adj. R-squared:                  0.946
# Method:                 Least Squares   F-statistic:                     426.8
# Date:                Tue, 12 Mar 2024   Prob (F-statistic):           7.29e-31
# Time:                        16:24:40   Log-Likelihood:                -526.83
# No. Observations:                  50   AIC:                             1060.
# Df Residuals:                      47   BIC:                             1065.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5.489e+04   6016.718      9.122      0.000    4.28e+04     6.7e+04
# ...

# %%
x_opt=x[:,[0,1]]
regressor_OLS=sm.OLS(endog=y,exog=x_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.947
# Model:                            OLS   Adj. R-squared:                  0.945
# Method:                 Least Squares   F-statistic:                     849.8
# Date:                Tue, 12 Mar 2024   Prob (F-statistic):           3.50e-32
# Time:                        16:24:40   Log-Likelihood:                -527.44
# No. Observations:                  50   AIC:                             1059.
# Df Residuals:                      48   BIC:                             1063.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       4.903e+04   2537.897     19.320      0.000    4.39e+04    5.41e+04
# ...

# %% [markdown]
# Estimating The Performance

# %% [raw]
# In the previous topic,we have bulild the model by using all independent features
# Now we will check the only one feature variable(R&D spend),Our dataset now looks like

# %%
df4=pd.read_csv('50_Startups.csv')

# %%
df4.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
df5=df4.drop(['Administration','Marketing Spend','State'],axis=1,inplace=True)

# %%
# final dataset 
df5

# %%
xx=df['R&D Spend']

# %%
xx
# Out:
# 0     165349.20
# 1     162597.70
# 2     153441.51
# 3     144372.41
# 4     142107.34
# 5     131876.90
# 6     134615.46
# 7     130298.13
# 8     120542.52
# 9     123334.88
# 10    101913.08
# 11    100671.96
# 12     93863.75
# 13     91992.39
# 14    119943.24
# 15    114523.61
# 16     78013.11
# 17     94657.16
# 18     91749.16
# 19     86419.70
# 20     76253.86
# 21     78389.47
# 22     73994.56
# 23     67532.53
# 24     77044.01
# 25     64664.71
# 26     75328.87
# 27     72107.60
# 28     66051.52
# 29     65605.48
# 30     61994.48
# 31     61136.38
# 32     63408.86
# 33     55493.95
# 34     46426.07
# 35     46014.02
# 36     28663.76
# 37     44069.95
# 38     20229.59
# 39     38558.51
# 40     28754.33
# 41     27892.92
# 42     23640.93
# 43     15505.73
# 44     22177.74
# 45      1000.23
# 46      1315.46
# 47         0.00
# 48       542.05
# 49         0.00
# Name: R&D Spend, dtype: float64

# %%
yy=df["Profit"]

# %%
yy
# Out:
# 0     192261.83
# 1     191792.06
# 2     191050.39
# 3     182901.99
# 4     166187.94
# 5     156991.12
# 6     156122.51
# 7     155752.60
# 8     152211.77
# 9     149759.96
# 10    146121.95
# 11    144259.40
# 12    141585.52
# 13    134307.35
# 14    132602.65
# 15    129917.04
# 16    126992.93
# 17    125370.37
# 18    124266.90
# 19    122776.86
# 20    118474.03
# 21    111313.02
# 22    110352.25
# 23    108733.99
# 24    108552.04
# 25    107404.34
# 26    105733.54
# 27    105008.31
# 28    103282.38
# 29    101004.64
# 30     99937.59
# 31     97483.56
# 32     97427.84
# 33     96778.92
# 34     96712.80
# 35     96479.51
# 36     90708.19
# 37     89949.14
# 38     81229.06
# 39     81005.76
# 40     78239.91
# 41     77798.83
# 42     71498.49
# 43     69758.98
# 44     65200.33
# 45     64926.08
# 46     49490.75
# 47     42559.73
# 48     35673.41
# 49     14681.40
# Name: Profit, dtype: float64

# %%
# spltting data
x_train,x_test,y_train,y_test=train_test_split(xx,yy,test_size=0.2,random_state=0)

# %%
x_test
# Out:
# 28     66051.52
# 11    100671.96
# 10    101913.08
# 41     27892.92
# 2     153441.51
# 27     72107.60
# 38     20229.59
# 31     61136.38
# 22     73994.56
# 4     142107.34
# Name: R&D Spend, dtype: float64

# %%
y_train
# Out:
# 33     96778.92
# 35     96479.51
# 26    105733.54
# 34     96712.80
# 18    124266.90
# 7     155752.60
# 14    132602.65
# 45     64926.08
# 48     35673.41
# 29    101004.64
# 15    129917.04
# 30     99937.59
# 32     97427.84
# 16    126992.93
# 42     71498.49
# 20    118474.03
# 43     69758.98
# 8     152211.77
# 13    134307.35
# 25    107404.34
# 5     156991.12
# 17    125370.37
# 40     78239.91
# 49     14681.40
# 1     191792.06
# 12    141585.52
# 37     89949.14
# 24    108552.04
# 6     156122.51
# 23    108733.99
# 36     90708.19
# 21    111313.02
# 19    122776.86
# 9     149759.96
# 39     81005.76
# 46     49490.75
# 3     182901.99
# 0     192261.83
# 47     42559.73
# 44     65200.33
# Name: Profit, dtype: float64

# %%
#fitting model

# %%
ree=LinearRegression()
ree.fit(np.array(x_train).reshape(-1,1),y_train)
# Out:
# LinearRegression()

# %% [raw]
# #Make the predictions one test set

# %%
#test
y_prd=ree.predict(np.array(x_test).reshape(-1,1))
y_prd
# Out:
# array([104667.27805998, 134150.83410578, 135207.80019517,  72170.54428856,
#        179090.58602508, 109824.77386586,  65644.27773757, 100481.43277139,
#        111431.75202432, 169438.14843539])

# %%
#
from sklearn.metrics import mean_squared_error, r2_score

MSE=mean_squared_error(y_test,y_prd)

r2 = r2_score(y_test,y_prd)

# %%
print("Coefficients:", ree.coef_)
print("Intercept:", ree.intercept_)
print("Mean Squared Error:", MSE)
print("R-squared:", r2)
# Out:
# Coefficients: [0.8516228]
# Intercept: 48416.297661385026
# Mean Squared Error: 68473440.71905932
# R-squared: 0.9464587607787219
